# %% [markdown]
# ## 서울시 공공자전거(따릉이) 이용현황 데이터 시각화

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_01.csv',encoding= 'CP949')
df2=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_02.csv',encoding= 'CP949')
df3=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_03.csv',encoding= 'CP949')
df4=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_04.csv',encoding= 'CP949')
df5=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_05.csv',encoding= 'CP949')
df6=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_06.csv',encoding= 'CP949') #12개월의 데이터들을 한번에 정리를 할경우 구글램에서 버티디를 못해서 우선 6개월씩 두번의 작업을 진행했습니다.
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df7=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_07.csv',encoding= 'CP949')
df8=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_08.csv',encoding= 'CP949')
df9=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_09.csv',encoding= 'CP949')
df10=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_10.csv',encoding= 'CP949')
df11=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_11.csv',encoding= 'CP949')
df12=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/2021_12.csv',encoding= 'CP949')

# %%
Data1=pd.concat([df1,df2,df3,df4,df5,df6], sort = True) #6개월 치의 데이터를 1번에 저장하고

# %%
Data2=pd.concat([df7,df8,df9,df10,df11,df12], sort = True) #7~12월의 데이터를 2번에 저장했습니다.

# %%
data1_1=Data1[Data1['대여 대여소명']=='강서구청'] #강서구청의 1~6월의 데이터들을 뽑고

# %%
data1_2=Data1[Data1['대여 대여소명']=='강남구청'] #강남구청의 1~6월의 데이터들을 뽑았습니다.

# %%
data2_1=Data2[Data2['대여 대여소명']=='강서구청'] #강서구청의 6~12월의 데이터들을 뽑고

# %%
Data1=pd.concat([df1,df2,df3,df4,df5,df6], sort = True) #6개월 치의 데이터를 1번에 저장하고
Data2=pd.concat([df7,df8,df9,df10,df11,df12], sort = True) #7~12월의 데이터를 2번에 저장했습니다.
data1_1=Data1[Data1['대여 대여소명']=='강서구청'] #강서구청의 1~6월의 데이터들을 뽑고
data1_2=Data1[Data1['대여 대여소명']=='강남구청'] #강남구청의 1~6월의 데이터들을 뽑았습니다.
data2_1=Data2[Data2['대여 대여소명']=='강서구청'] #강서구청의 6~12월의 데이터들을 뽑고
data2_2=Data2[Data2['대여 대여소명']=='강서구청'] #강남구청의 6~12월의 데이터들을 뽑았습니다.

# %%
row_data1=pd.concat([data1_1,data1_2], sort = True) #1~6월의 데이터들을 합하고

# %%
row_data2=pd.concat([data2_1,data2_2], sort = True) #7~12월의 데이터들을 합쳐서

# %%
row_data1.to_csv('전체데이터1.csv') #이를 1번 csv

# %%
row_data2.to_csv('전체데이터2.csv') #2번 csv로 저장했습니다.
