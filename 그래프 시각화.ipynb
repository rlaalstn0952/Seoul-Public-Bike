# %% [markdown]
# # (강남구청, 강서구청)
# # 시각화 (월 -> 요일 -> 시간-> 구간별)

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## csv 데이터 불러오기

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
raw_data = pd.read_csv("/content/drive/MyDrive/ITStudy/전체데이터.csv", encoding='utf-8')
raw_data
# Out:
#        Unnamed: 0 대여 대여소명  대여 대여소번호                 대여일시  \
# 0               0    강서구청      1157  2021-01-01 00:20:20
# 1               1    강서구청      1157  2021-01-01 00:56:07
# 2               2    강서구청      1157  2021-01-01 00:51:29
# 3               3    강서구청      1157  2021-01-01 02:52:07
# 4               4    강서구청      1157  2021-01-01 07:57:49
# ...           ...     ...       ...                  ...
# 31995       31995    강남구청      2356  2021-12-30 20:19:05
# 31996       31996    강남구청      2356  2021-12-31 07:03:27
# 31997       31997    강남구청      2356  2021-12-31 15:58:54
# 31998       31998    강남구청      2356  2021-12-31 14:54:10
# 31999       31999    강남구청      2356  2021-12-31 17:29:41
#
#                          반납대여소명  반납대여소번호                 반납일시      이용거리   이용시간
# 0                     KBS 스포츠월드     1182  2021-01-01 00:27:17      0.00    6.0
# 1                        KC 대학교     1183  2021-01-01 01:00:41    483.16    4.0
# ...

# %%
df = raw_data.copy()
df.head()
# Out:
#    Unnamed: 0 대여 대여소명  대여 대여소번호                 대여일시  \
# 0           0    강서구청      1157  2021-01-01 00:20:20
# 1           1    강서구청      1157  2021-01-01 00:56:07
# 2           2    강서구청      1157  2021-01-01 00:51:29
# 3           3    강서구청      1157  2021-01-01 02:52:07
# 4           4    강서구청      1157  2021-01-01 07:57:49
#
#                      반납대여소명  반납대여소번호                 반납일시     이용거리  이용시간
# 0                 KBS 스포츠월드     1182  2021-01-01 00:27:17     0.00   6.0
# 1                    KC 대학교     1183  2021-01-01 01:00:41   483.16   4.0
# 2                까치산역 3번 출구     2737  2021-01-01 01:08:45  2497.24  17.0
# 3                      으뜸공원      740  2021-01-01 03:04:32     0.00  12.0
# 4  증미역 3번출구뒤(등촌두산위브센티움오피스텔)     1118  2021-01-01 08:08:04     0.00  10.0

# %%
df
# Out:
#        Unnamed: 0 대여 대여소명  대여 대여소번호                 대여일시  \
# 0               0    강서구청      1157  2021-01-01 00:20:20
# 1               1    강서구청      1157  2021-01-01 00:56:07
# 2               2    강서구청      1157  2021-01-01 00:51:29
# 3               3    강서구청      1157  2021-01-01 02:52:07
# 4               4    강서구청      1157  2021-01-01 07:57:49
# ...           ...     ...       ...                  ...
# 31995       31995    강남구청      2356  2021-12-30 20:19:05
# 31996       31996    강남구청      2356  2021-12-31 07:03:27
# 31997       31997    강남구청      2356  2021-12-31 15:58:54
# 31998       31998    강남구청      2356  2021-12-31 14:54:10
# 31999       31999    강남구청      2356  2021-12-31 17:29:41
#
#                          반납대여소명  반납대여소번호                 반납일시      이용거리   이용시간
# 0                     KBS 스포츠월드     1182  2021-01-01 00:27:17      0.00    6.0
# 1                        KC 대학교     1183  2021-01-01 01:00:41    483.16    4.0
# ...

# %%
df.drop(columns=['Unnamed: 0', '대여 대여소번호', '반납대여소번호','이용거리', '이용시간'], axis=1,inplace = True)

# %%
df.head()
# Out:
#   대여 대여소명                 대여일시                    반납대여소명                 반납일시
# 0    강서구청  2021-01-01 00:20:20                 KBS 스포츠월드  2021-01-01 00:27:17
# 1    강서구청  2021-01-01 00:56:07                    KC 대학교  2021-01-01 01:00:41
# 2    강서구청  2021-01-01 00:51:29                까치산역 3번 출구  2021-01-01 01:08:45
# 3    강서구청  2021-01-01 02:52:07                      으뜸공원  2021-01-01 03:04:32
# 4    강서구청  2021-01-01 07:57:49  증미역 3번출구뒤(등촌두산위브센티움오피스텔)  2021-01-01 08:08:04

# %%
df.tail()
# Out:
#       대여 대여소명                 대여일시                 반납대여소명                 반납일시
# 31995    강남구청  2021-12-30 20:19:05      롯데월드타워(잠실역2번출구 쪽)  2021-12-30 20:58:54
# 31996    강남구청  2021-12-31 07:03:27  르네상스호텔사거리 역삼지하보도 2번출구  2021-12-31 07:32:35
# 31997    강남구청  2021-12-31 15:58:54           포스코사거리(기업은행)  2021-12-31 16:10:32
# 31998    강남구청  2021-12-31 14:54:10                청담나들목입구  2021-12-31 16:48:38
# 31999    강남구청  2021-12-31 17:29:41           포스코사거리(기업은행)  2021-12-31 17:39:30

# %% [markdown]
# ## 대여일 데이터 처리 - 월, 요일, 시간 분리

# %% [markdown]
# ### 대여일, 시간 분리

# %%
# 대여일로 대여 요일구하여 컬럼 추가하기
from datetime import datetime

# 대여일 data type을 datetime으로 변경
df['대여일시'] = pd.to_datetime(df['대여일시'])

# dt.weekday 함수로 대여일 요일 변환, 컬럼 추가(Monday=0, Sunday=6)
df['대여 월'] = df['대여일시'].dt.month
df['대여 시간'] = df['대여일시'].dt.hour
df['대여 요일'] = df['대여일시'].dt.weekday

# %%
df.head()
# Out:
#   대여 대여소명                대여일시                    반납대여소명                 반납일시  \
# 0    강서구청 2021-01-01 00:20:20                 KBS 스포츠월드  2021-01-01 00:27:17
# 1    강서구청 2021-01-01 00:56:07                    KC 대학교  2021-01-01 01:00:41
# 2    강서구청 2021-01-01 00:51:29                까치산역 3번 출구  2021-01-01 01:08:45
# 3    강서구청 2021-01-01 02:52:07                      으뜸공원  2021-01-01 03:04:32
# 4    강서구청 2021-01-01 07:57:49  증미역 3번출구뒤(등촌두산위브센티움오피스텔)  2021-01-01 08:08:04
#
#    대여 요일  대여 월  대여 시간
# 0      4     1      0
# 1      4     1      0
# 2      4     1      0
# 3      4     1      2
# 4      4     1      7

# %% [markdown]
# ## 강남/강서 데이터 분리 (월, 요일)

# %%
# 강남구청 kn_df
kn_df = df[df['대여 대여소명']=='강남구청'].copy().reset_index(drop=True)
kn_df.head()
# Out:
#   대여 대여소명                대여일시               반납대여소명                 반납일시  \
# 0    강남구청 2021-01-01 22:01:51            청담공원앞 교차로  2021-01-01 22:05:35
# 1    강남구청 2021-01-01 23:42:43            한국우편사업진흥원  2021-01-01 23:54:47
# 2    강남구청 2021-01-02 12:35:03  삼성중앙역4번출구(문화센터더 리빌)  2021-01-02 12:43:06
# 3    강남구청 2021-01-03 12:52:29  삼성중앙역4번출구(문화센터더 리빌)  2021-01-03 13:01:40
# 4    강남구청 2021-01-04 13:26:02    신영 ROYAL PALACE 앞  2021-01-04 13:44:32
#
#    대여 요일  대여 월  대여 시간
# 0      4     1     22
# 1      4     1     23
# 2      5     1     12
# 3      6     1     12
# 4      0     1     13

# %%
# 요일, 월 별 이용자 수 df 만들기
kn_week = pd.DataFrame(kn_df['대여 요일'].value_counts().sort_index())
kn_week = kn_week.rename(columns={'대여 요일':'강남구청'})

kn_month = pd.DataFrame(kn_df['대여 월'].value_counts().sort_index())
kn_month = kn_month.rename(columns={'대여 월':'강남구청'})

# %%
kn_month
# Out:
#     강남구청
# 1    132
# 2    186
# 3    448
# 4    625
# 5    544
# 6    473
# 7    360
# 8    530
# 9    497
# 10   407
# 11   312
# 12   194

# %%
kn_week
# Out:
#    강남구청
# 0   779
# 1   635
# 2   735
# 3   759
# 4   663
# 5   533
# 6   604

# %%
# 강서구청 ks
ks_df = df.loc[df['대여 대여소명'] == '강서구청'].copy().reset_index(drop=True)
ks_df.head()
# Out:
#   대여 대여소명                대여일시                    반납대여소명                 반납일시  \
# 0    강서구청 2021-01-01 00:20:20                 KBS 스포츠월드  2021-01-01 00:27:17
# 1    강서구청 2021-01-01 00:56:07                    KC 대학교  2021-01-01 01:00:41
# 2    강서구청 2021-01-01 00:51:29                까치산역 3번 출구  2021-01-01 01:08:45
# 3    강서구청 2021-01-01 02:52:07                      으뜸공원  2021-01-01 03:04:32
# 4    강서구청 2021-01-01 07:57:49  증미역 3번출구뒤(등촌두산위브센티움오피스텔)  2021-01-01 08:08:04
#
#    대여 요일  대여 월  대여 시간
# 0      4     1      0
# 1      4     1      0
# 2      4     1      0
# 3      4     1      2
# 4      4     1      7

# %%
ks_week = pd.DataFrame(ks_df['대여 요일'].value_counts().sort_index())
ks_week = ks_week.rename(columns={'대여 요일':'강서구청'})

ks_month = pd.DataFrame(ks_df['대여 월'].value_counts().sort_index())
ks_month = ks_month.rename(columns={'대여 월':'강서구청'})

# %%
ks_week
# Out:
#    강서구청
# 0  3954
# 1  3947
# 2  4565
# 3  4464
# 4  4403
# 5  3088
# 6  2871

# %%
ks_month
# Out:
#     강서구청
# 1    752
# 2   1088
# 3   1921
# 4   2442
# 5   2601
# 6   3127
# 7   2913
# 8   2741
# 9   2936
# 10  2711
# 11  2146
# 12  1914

# %% [markdown]
# ## 월 별 합치기

# %%
df['대여 월'].value_counts().sort_index()
# Out:
# 1      884
# 2     1274
# 3     2369
# 4     3067
# 5     3145
# 6     3600
# 7     3273
# 8     3271
# 9     3433
# 10    3118
# 11    2458
# 12    2108
# Name: 대여 월, dtype: int64

# %%
total_month = pd.DataFrame(df['대여 월'].value_counts().sort_index())
total_month['월']=['Jan.','Feb.','Mar.','Apr.','May.','Jun.','Jul.','Aug.','Sep.','Oct.','Nov.','Dec.']

# %%
total_month = total_month.rename(columns={'대여 월':'총 수'})

# %%
total_month = total_month.join(kn_month, how='inner')
total_month = total_month.join(ks_month, how='inner')
total_month = total_month.set_index(keys=['월'], inplace=False, drop=True)

# %%
total_month
# Out:
#        총 수  강남구청  강서구청
# 월
# Jan.   884   132   752
# Feb.  1274   186  1088
# Mar.  2369   448  1921
# Apr.  3067   625  2442
# May.  3145   544  2601
# Jun.  3600   473  3127
# Jul.  3273   360  2913
# Aug.  3271   530  2741
# Sep.  3433   497  2936
# Oct.  3118   407  2711
# Nov.  2458   312  2146
# Dec.  2108   194  1914

# %% [markdown]
# ## 요일별 합치기

# %%
df['대여 요일'].value_counts()
# Out:
# 2    5300
# 3    5223
# 4    5066
# 0    4733
# 1    4582
# 5    3621
# 6    3475
# Name: 대여 요일, dtype: int64

# %%
total_week = pd.DataFrame(df['대여 요일'].value_counts().sort_index())
total_week['요일'] = pd.DataFrame(['월','화','수','목','금','토','일'])

# %%
total_week = total_week.rename(columns={'대여 요일':'총 수'})

# %%
total_week
# Out:
#     총 수 요일
# 0  4733  월
# 1  4582  화
# 2  5300  수
# 3  5223  목
# 4  5066  금
# 5  3621  토
# 6  3475  일

# %%
# kn_week, ks_week data merge
total_week = total_week.join(kn_week, how='inner')
total_week = total_week.join(ks_week, how='inner')

# %%
total_week=total_week.set_index(keys=['요일'], inplace=False, drop=True)

# %%
total_week
# Out:
#      총 수  강남구청  강서구청
# 요일
# 월   4733   779  3954
# 화   4582   635  3947
# 수   5300   735  4565
# 목   5223   759  4464
# 금   5066   663  4403
# 토   3621   533  3088
# 일   3475   604  2871

# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# ## 시각화 tool 설정

# %%
import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm # 폰트 관련 용도
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import numpy as np
import pandas as pd

# 현재 설치된 폰트 확인해보기
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")
print(sys_font)

nanum_font = [f for f in sys_font if 'Nanum' in f]
print(f"nanum_font number: {len(nanum_font)}")
import plotly.graph_objects as go
import plotly.io as pio 
pio.templates.default = "plotly_dark"
# Out:
# sys_font number: 17
# ...

# %% [markdown]
# ### 시각화

# %% [markdown]
# https://zephyrus1111.tistory.com/167

# %% [markdown]
# ## 월별 이용자 수 추이

# %%
total_month
# Out:
#        총 수  강남구청  강서구청
# 월
# Jan.   884   132   752
# Feb.  1274   186  1088
# Mar.  2369   448  1921
# Apr.  3067   625  2442
# May.  3145   544  2601
# Jun.  3600   473  3127
# Jul.  3273   360  2913
# Aug.  3271   530  2741
# Sep.  3433   497  2936
# Oct.  3118   407  2711
# Nov.  2458   312  2146
# Dec.  2108   194  1914

# %%
fig = px.pie(total_month, values='총 수', title='강남/강서 전체 월별 사용자 비율', names=total_month.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
d3 = go.Bar(x=total_month.index, y=total_month['강남구청'], name='강남구청')
d4 = go.Bar(x=total_month.index, y=total_month['강서구청'], name='강서구청')
layout = go.Layout(title='강남/강서 구청 월별 이용자 수')
fig = go.Figure(data=[d3,d4], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
d3 = go.Bar(x=total_month.index, y=total_month['강남구청'], name='강남구청')
d4 = go.Bar(x=total_month.index, y=total_month['강서구청'], name='강서구청')
layout = go.Layout(title='강남/강서 구청 월별 이용자 수', barmode='stack')
fig = go.Figure(data=[d3,d4], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 월별 따릉이 이용자 수 (강남 + 강서)
import plotly.graph_objects as go
import plotly.io as pio 
pio.templates.default = "plotly_dark"
fig = go.Figure(go.Scatter(
    x = total_month.index,
    y = total_month['총 수'],

))

fig.update_layout(
    xaxis = dict(
        title ='월별 따릉이 이용자 수',
        tickmode = 'linear',
        tick0 = 0,
        dtick = 0.75
    )
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 요일 별 이용자 수

# %%
total_week
# Out:
#      총 수  강남구청  강서구청
# 요일
# 월   4733   779  3954
# 화   4582   635  3947
# 수   5300   735  4565
# 목   5223   759  4464
# 금   5066   663  4403
# 토   3621   533  3088
# 일   3475   604  2871

# %%
d1 = go.Bar(x=total_week.index, y=total_week['강남구청'], name='강남구청')
d2 = go.Bar(x=total_week.index, y=total_week['강서구청'], name='강서구청')
layout = go.Layout(title='강남/강서 구청 별 요일에 따른 이용자 수')
fig = go.Figure(data=[d1,d2], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
d1 = go.Bar(x=total_week.index, y=total_week['강남구청'], name='강남구청')
d2 = go.Bar(x=total_week.index, y=total_week['강서구청'], name='강서구청')
layout = go.Layout(title='강남/강서 구청 별 요일에 따른 이용자 수',barmode='stack')
fig = go.Figure(data=[d1,d2], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# colors = sns.color_palette('hls', len(total_week.index))
fig = px.bar(total_week, title='강남/강서 요일 별 이용자 수', x=total_week.index, y='총 수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 시간 별 이용자 수

# %%
ks_df['대여일시']
# Out:
# 0       2021-01-01 00:20:20
# 1       2021-01-01 00:56:07
# 2       2021-01-01 00:51:29
# 3       2021-01-01 02:52:07
# 4       2021-01-01 07:57:49
#                 ...
# 27287   2021-12-31 19:57:42
# 27288   2021-12-31 20:33:25
# 27289   2021-12-31 21:07:12
# 27290   2021-12-31 20:36:40
# 27291   2021-12-31 23:53:03
# Name: 대여일시, Length: 27292, dtype: datetime64[ns]

# %%
kn_df
# Out:
#      대여 대여소명                대여일시                 반납대여소명                 반납일시  \
# 0       강남구청 2021-01-01 22:01:51              청담공원앞 교차로  2021-01-01 22:05:35
# 1       강남구청 2021-01-01 23:42:43              한국우편사업진흥원  2021-01-01 23:54:47
# 2       강남구청 2021-01-02 12:35:03    삼성중앙역4번출구(문화센터더 리빌)  2021-01-02 12:43:06
# 3       강남구청 2021-01-03 12:52:29    삼성중앙역4번출구(문화센터더 리빌)  2021-01-03 13:01:40
# 4       강남구청 2021-01-04 13:26:02      신영 ROYAL PALACE 앞  2021-01-04 13:44:32
# ...      ...                 ...                    ...                  ...
# 4703    강남구청 2021-12-30 20:19:05      롯데월드타워(잠실역2번출구 쪽)  2021-12-30 20:58:54
# 4704    강남구청 2021-12-31 07:03:27  르네상스호텔사거리 역삼지하보도 2번출구  2021-12-31 07:32:35
# 4705    강남구청 2021-12-31 15:58:54           포스코사거리(기업은행)  2021-12-31 16:10:32
# 4706    강남구청 2021-12-31 14:54:10                청담나들목입구  2021-12-31 16:48:38
# 4707    강남구청 2021-12-31 17:29:41           포스코사거리(기업은행)  2021-12-31 17:39:30
#
#       대여 요일  대여 월  대여 시간
# ...

# %%
# 시간별 이용자 수 리스트로 만들기 함수
def hour_sum(wh):

  hours = [0 for a in range(24)]

  for i in range(24):
    hours[i] = len(wh.loc[wh['대여일시'].dt.hour == i])

  return hours

# %%
ks_hours = hour_sum(ks_df)
kn_hours = hour_sum(kn_df) 
total_hours = hour_sum(df)

# %%
ks_hours
# Out:
# [367,
#  318,
#  265,
#  179,
#  92,
#  138,
#  728,
#  1113,
#  2920,
#  1487,
#  1010,
#  1262,
#  1027,
#  1201,
#  1243,
#  1278,
#  1434,
#  1751,
#  2680,
#  1629,
#  1535,
#  1587,
#  1424,
#  624]

# %%
# sum(ks_hours)
# sum(kn_hours)
# sum(total_hours)

# %%
hour_li = [i for i in range(24)]

# %%
# 시간별 강서
import plotly.graph_objects as go
import plotly.io as pio 
pio.templates.default = "plotly_dark"
fig = go.Figure(go.Scatter(
    x = hour_li,
    y = ks_hours, # 강서구청

))

fig.update_layout(
    xaxis = dict(
        title ='강서구청 시간별 따릉이 이용자 수',
        tickmode = 'linear',
        tick0 = 0,
        dtick = 0
    )
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 시간별 강남
import plotly.graph_objects as go
import plotly.io as pio 
pio.templates.default = "plotly_dark"
fig = go.Figure(go.Scatter(
    x = hour_li,
    y = kn_hours,

))

fig.update_layout(
    xaxis = dict(
        title ='강남구청 시간별 따릉이 이용자 수',
        tickmode = 'linear',
        tick0 = 0,
        dtick = 0
    )
)
# fig.update_yaxes(range=[0, 3000])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 시간별 강남+강서
import plotly.graph_objects as go
import plotly.io as pio 
pio.templates.default = "plotly_dark"
fig = go.Figure(go.Scatter(
    x = hour_li,
    y = total_hours,

))

fig.update_layout(
    xaxis = dict(
        title ='시간별 따릉이 이용자 수',
        tickmode = 'linear',
        tick0 = 0,
        dtick = 0
    )
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 시간 구간대 별 이용자 수

# %%
import warnings 
warnings.filterwarnings('ignore') # Warning 안뜨게 하기

# %%
ks_df_1 = ks_df.copy()

# %%
for i in range(len(ks_df_1)):
  ks_df_1['대여일시'][i] = str(df['대여일시'][i]).split(':')[0][-2:]

# %%
time1 = [] # 시간대 리스트
for i in range(len(ks_df_1)):
  time1.append(ks_df_1['대여일시'][i])

# %%
ks_df_dawn =  time1.count('03') + time1.count('04')+ time1.count('05') #새벽
ks_df_moring = time1.count('06') + time1.count('07') + time1.count('08') # 아침
ks_df_brunch = time1.count('09') + time1.count('10') + time1.count('11') # 오전 
ks_df_lunch = time1.count('12') + time1.count('13') # 점심
ks_df_afternoon =  time1.count('14') + time1.count('15') + time1.count('16') + time1.count('17') # 오후
ks_df_evening = time1.count('18') + time1.count('19') + time1.count('20') # 저녁
ks_df_night = time1.count('21') + time1.count('22') + time1.count('23') # 밤
ks_df_midnight = time1.count('00') + time1.count('01') + time1.count('02') # 자정이후

# %%
dict1_time = {'시간대':['새벽','아침','오전','점심','오후','저녁','밤','자정 이후'],
            '대여수':[ks_df_dawn,ks_df_moring,ks_df_brunch,ks_df_lunch,ks_df_afternoon,ks_df_evening,ks_df_night,ks_df_midnight]}
ks_df_time = pd.DataFrame(dict1_time)

# %%
kn_df_1 = kn_df.copy()

# %%
for i in range(len(kn_df_1)):
  kn_df_1['대여일시'][i] = str(df['대여일시'][i]).split(':')[0][-2:]

# %%
time2 = [] # 시간대 리스트
for i in range(len(kn_df_1)):
  time2.append(kn_df_1['대여일시'][i])

# %%
kn_df_dawn =  time2.count('03') + time2.count('04')+ time2.count('05') #새벽
kn_df_moring = time2.count('06') + time2.count('07') + time2.count('08') # 아침
kn_df_brunch = time2.count('09') + time2.count('10') + time2.count('11') # 오전 
kn_df_lunch = time2.count('12') + time2.count('13') # 점심
kn_df_afternoon =  time2.count('14') + time2.count('15') + time2.count('16') + time2.count('17') # 오후
kn_df_evening = time2.count('18') + time2.count('19') + time2.count('20') # 저녁
kn_df_night = time2.count('21') + time2.count('22') + time2.count('23') # 밤
kn_df_midnight = time2.count('00') + time2.count('01') + time2.count('02') # 자정이후

# %%
dict2_time = {'시간대':['새벽','아침','오전','점심','오후','저녁','밤','자정 이후'],
            '대여수':[kn_df_dawn,kn_df_moring,kn_df_brunch,kn_df_lunch,kn_df_afternoon,kn_df_evening,kn_df_night,kn_df_midnight]}
kn_df_time = pd.DataFrame(dict2_time)

# %%
b1 = go.Line(x=ks_df_time['시간대'], y=ks_df_time['대여수'], name='강서구청')
b2 = go.Line(x=kn_df_time['시간대'], y=kn_df_time['대여수'], name='강남구청')
layout = go.Layout(title='2021년 시간대별 강남/강서 구청 대여소 따릉이 대여 현황',
                   xaxis={'title':'시간대'},yaxis={'title':'대여수'})
fig = go.Figure(data=[b1,b2], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
