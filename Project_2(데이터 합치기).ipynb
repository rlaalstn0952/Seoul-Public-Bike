# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/전체데이터1.csv')
df2=pd.read_csv('/content/drive/MyDrive/ITSTUDY/Project1/전체데이터2.csv') #전체 데이터 1,2,번을 불러와서

# %%
df2
# Out:
#        Unnamed: 0 대여 대여소명  대여 대여소번호  대여거치대                 대여일시  반납거치대  \
# 0         1359358    강서구청      1157      0  2021-07-01 00:15:08      0
# 1         1359359    강서구청      1157      0  2021-07-01 00:56:56      0
# 2         1359360    강서구청      1157      0  2021-07-01 00:48:44      0
# 3         1359361    강서구청      1157      0  2021-07-01 02:02:55      0
# 4         1359362    강서구청      1157      0  2021-07-01 02:11:03      0
# ...           ...     ...       ...    ...                  ...    ...
# 17656     1208915    강남구청      2356      0  2021-12-30 20:19:05      0
# 17657     1208916    강남구청      2356      0  2021-12-31 07:03:27      0
# 17658     1208917    강남구청      2356      0  2021-12-31 15:58:54      0
# 17659     1208918    강남구청      2356      0  2021-12-31 14:54:10      0
# 17660     1208919    강남구청      2356      0  2021-12-31 17:29:41      0
#
#                       반납대여소명  반납대여소번호                 반납일시      이용거리  이용시간  \
# ...

# %%
Data=pd.concat([df1,df2], sort = True)  #이 두개의 데이터들을 합쳤습니다.

# %%
Data=Data.drop(columns=['Unnamed: 0'] )# 필요없는 인덱스값들을 제거하고

# %%
Data=Data.reset_index().drop(columns=['index']) # 인덱스 값들을 재설정해서

# %%
Data=Data.drop(['자전거번호','대여거치대','반납거치대'],axis=1) # 불필요한 columns 삭제

# %%
Data.to_csv('전체데이터.csv') #다시 다른 데이터들로 저장했습니다.
